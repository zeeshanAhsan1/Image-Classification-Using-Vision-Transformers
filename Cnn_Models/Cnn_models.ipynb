# %% [markdown]
# # Analysis of Skin Lesion Classification using Transfer Learning Models

# %% [markdown]
#  ### First, import all libraries that used in this project

# %%
# %matplotlib inline
# python libraties
import os, cv2,itertools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm
from glob import glob
from PIL import Image

# pytorch libraries
import torch
from torch import optim,nn
from torch.autograd import Variable
from torch.utils.data import DataLoader,Dataset
from torchvision import models,transforms

# sklearn libraries
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

import zipfile
from google.colab import drive

drive.mount('/content/drive')

# !unzip -u "/content/drive/MyDrive/archive.zip" -d "./input"

# to make the results are reproducible
np.random.seed(10)
torch.manual_seed(10)
torch.cuda.manual_seed(10)

print(os.listdir("./input"))
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./input/ham10000_images_part_2/ISIC_0029326.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029327.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029328.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029329.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029330.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029331.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029332.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029333.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029334.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029335.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029336.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029337.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029338.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029339.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029340.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029341.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029342.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029343.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029344.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029345.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029346.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029347.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029348.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029349.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029350.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029351.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029352.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029353.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029354.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029355.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029356.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029357.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029358.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029359.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029360.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029361.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029362.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029363.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029364.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029365.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029366.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029367.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029368.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029369.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029370.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029371.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029372.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029373.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029374.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029375.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029376.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029377.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029378.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029379.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029380.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029381.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029382.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029383.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029384.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029385.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029386.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029387.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029388.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029389.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029390.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029391.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029392.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029393.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029394.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029395.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029396.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029397.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029398.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029399.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029400.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029401.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029402.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029403.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029404.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029405.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029406.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029407.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029408.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029409.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029410.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029411.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029412.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029413.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029414.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029415.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029416.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029417.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029418.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029419.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029420.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029421.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029422.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029423.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029424.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029425.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029426.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029427.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029428.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029429.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029430.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029431.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029432.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029433.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029434.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029435.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029436.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029437.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029438.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029439.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029440.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029441.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029442.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029443.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029444.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029445.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029446.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029447.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029448.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029449.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029450.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029451.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029452.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029453.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029454.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029455.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029456.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029457.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029458.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029459.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029460.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029461.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029462.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029463.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029464.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029465.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029466.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029467.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029468.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029469.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029470.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029471.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029472.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029473.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029474.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029475.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029476.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029477.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029478.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029479.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029480.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029481.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029482.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029483.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029484.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029485.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029486.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029487.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029488.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029489.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029490.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029491.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029492.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029493.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029494.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029495.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029496.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029497.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029498.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029499.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029500.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029501.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029502.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029503.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029504.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029505.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029506.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029507.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029508.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029509.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029510.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029511.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029512.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029513.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029514.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029515.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029516.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029517.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029518.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029519.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029520.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029521.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029522.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029523.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029524.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029525.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029526.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029527.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029528.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029529.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029530.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029531.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029532.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029533.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029534.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029535.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029536.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029537.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029538.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029539.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029540.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029541.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029542.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029543.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029544.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029545.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029546.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029547.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029548.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029549.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029550.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029551.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029552.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029553.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029554.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029555.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029556.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029557.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029558.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029559.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029560.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029561.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029562.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029563.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029564.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029565.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029566.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029567.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029568.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029569.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029570.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029571.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029572.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029573.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029574.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029575.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029576.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029577.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029578.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029579.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029580.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029581.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029582.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029583.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029584.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029585.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029586.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029587.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029588.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029589.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029590.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029591.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029592.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029593.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029594.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029595.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029596.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029597.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029598.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029599.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029600.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029601.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029602.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029603.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029604.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029605.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029606.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029607.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029608.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029609.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029610.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029611.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029612.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029613.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029614.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029615.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029616.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029617.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029618.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029619.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029620.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029621.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029622.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029623.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029624.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029625.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029626.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029627.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029628.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029629.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029630.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029631.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029632.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029633.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029634.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029635.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029636.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029637.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029638.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029639.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029640.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029641.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029642.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029643.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029644.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029645.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029646.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029647.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029648.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029649.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029650.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029651.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029652.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029653.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029654.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029655.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029656.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029657.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029658.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029659.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029660.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029661.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029662.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029663.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029664.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029665.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029666.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029667.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029668.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029669.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029670.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029671.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029672.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029673.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029674.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029675.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029676.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029677.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029678.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029679.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029680.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029681.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029682.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029683.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029684.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029685.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029686.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029687.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029688.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029689.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029690.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029691.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029692.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029693.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029694.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029695.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029696.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029697.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029698.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029699.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029700.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029701.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029702.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029703.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029704.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029705.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029706.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029707.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029708.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029709.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029710.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029711.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029712.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029713.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029714.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029715.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029716.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029717.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029718.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029719.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029720.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029721.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029722.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029723.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029724.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029725.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029726.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029727.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029728.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029729.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029730.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029731.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029732.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029733.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029734.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029735.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029736.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029737.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029738.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029739.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029740.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029741.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029742.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029743.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029744.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029745.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029746.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029747.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029748.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029749.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029750.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029751.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029752.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029753.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029754.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029755.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029756.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029757.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029758.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029759.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029760.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029761.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029762.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029763.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029764.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029765.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029766.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029767.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029768.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029769.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029770.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029771.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029772.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029773.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029774.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029775.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029776.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029777.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029778.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029779.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029780.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029781.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029782.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029783.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029784.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029785.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029786.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029787.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029788.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029789.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029790.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029791.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029792.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029793.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029794.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029795.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029796.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029797.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029798.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029799.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029800.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029801.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029802.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029803.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029804.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029805.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029806.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029807.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029808.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029809.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029810.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029811.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029812.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029813.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029814.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029815.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029816.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029817.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029818.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029819.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029820.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029821.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029822.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029823.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029824.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029825.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029826.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029827.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029828.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029829.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029830.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029831.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029832.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029833.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029834.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029835.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029836.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029837.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029838.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029839.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029840.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029841.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029842.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029843.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029844.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029845.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029846.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029847.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029848.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029849.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029850.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029851.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029852.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029853.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029854.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029855.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029856.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029857.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029858.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029859.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029860.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029861.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029862.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029863.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029864.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029865.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029866.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029867.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029868.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029869.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029870.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029871.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029872.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029873.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029874.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029875.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029876.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029877.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029878.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029879.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029880.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029881.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029882.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029883.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029884.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029885.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029886.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029887.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029888.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029889.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029890.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029891.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029892.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029893.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029894.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029895.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029896.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029897.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029898.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029899.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029900.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029901.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029902.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029903.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029904.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029905.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029906.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029907.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029908.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029909.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029910.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029911.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029912.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029913.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029914.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029915.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029916.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029917.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029918.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029919.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029920.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029921.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029922.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029923.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029924.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029925.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029926.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029927.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029928.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029929.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029930.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029931.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029932.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029933.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029934.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029935.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029936.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029937.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029938.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029939.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029940.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029941.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029942.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029943.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029944.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029945.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029946.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029947.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029948.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029949.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029950.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029951.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029952.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029953.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029954.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029955.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029956.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029957.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029958.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029959.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029960.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029961.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029962.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029963.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029964.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029965.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029966.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029967.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029968.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029969.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029970.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029971.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029972.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029973.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029974.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029975.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029976.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029977.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029978.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029979.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029980.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029981.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029982.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029983.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029984.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029985.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029986.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029987.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029988.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029989.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029990.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029991.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029992.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029993.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029994.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029995.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029996.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029997.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029998.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0029999.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030000.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030001.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030002.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030003.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030004.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030005.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030006.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030007.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030008.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030009.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030010.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030011.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030012.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030013.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030014.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030015.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030016.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030017.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030018.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030019.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030020.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030021.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030022.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030023.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030024.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030025.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030026.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030027.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030028.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030029.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030030.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030031.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030032.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030033.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030034.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030035.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030036.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030037.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030038.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030039.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030040.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030041.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030042.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030043.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030044.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030045.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030046.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030047.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030048.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030049.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030050.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030051.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030052.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030053.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030054.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030055.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030056.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030057.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030058.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030059.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030060.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030061.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030062.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030063.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030064.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030065.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030066.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030067.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030068.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030069.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030070.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030071.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030072.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030073.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030074.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030075.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030076.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030077.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030078.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030079.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030080.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030081.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030082.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030083.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030084.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030085.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0030086.jpg
# ...
#   inflating: ./input/ham10000_images_part_2/ISIC_0034074.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034075.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034076.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034077.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034078.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034079.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034080.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034081.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034082.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034083.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034084.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034085.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034086.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034087.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034088.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034089.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034090.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034091.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034092.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034093.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034094.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034095.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034096.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034097.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034098.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034099.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034100.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034101.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034102.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034103.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034104.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034105.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034106.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034107.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034108.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034109.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034110.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034111.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034112.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034113.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034114.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034115.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034116.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034117.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034118.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034119.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034120.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034121.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034122.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034123.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034124.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034125.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034126.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034127.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034128.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034129.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034130.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034131.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034132.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034133.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034134.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034135.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034136.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034137.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034138.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034139.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034140.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034141.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034142.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034143.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034144.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034145.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034146.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034147.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034148.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034149.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034150.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034151.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034152.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034153.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034154.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034155.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034156.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034157.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034158.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034159.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034160.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034161.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034162.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034163.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034164.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034165.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034166.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034167.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034168.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034169.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034170.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034171.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034172.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034173.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034174.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034175.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034176.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034177.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034178.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034179.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034180.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034181.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034182.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034183.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034184.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034185.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034186.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034187.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034188.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034189.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034190.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034191.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034192.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034193.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034194.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034195.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034196.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034197.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034198.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034199.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034200.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034201.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034202.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034203.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034204.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034205.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034206.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034207.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034208.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034209.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034210.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034211.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034212.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034213.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034214.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034215.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034216.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034217.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034218.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034219.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034220.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034221.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034222.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034223.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034224.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034225.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034226.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034227.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034228.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034229.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034230.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034231.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034232.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034233.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034234.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034235.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034236.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034237.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034238.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034239.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034240.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034241.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034242.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034243.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034244.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034245.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034246.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034247.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034248.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034249.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034250.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034251.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034252.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034253.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034254.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034255.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034256.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034257.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034258.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034259.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034260.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034261.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034262.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034263.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034264.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034265.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034266.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034267.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034268.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034269.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034270.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034271.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034272.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034273.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034274.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034275.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034276.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034277.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034278.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034279.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034280.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034281.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034282.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034283.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034284.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034285.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034286.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034287.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034288.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034289.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034290.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034291.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034292.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034293.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034294.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034295.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034296.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034297.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034298.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034299.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034300.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034301.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034302.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034303.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034304.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034305.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034306.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034307.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034308.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034309.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034310.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034311.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034312.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034313.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034314.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034315.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034316.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034317.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034318.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034319.jpg
#   inflating: ./input/ham10000_images_part_2/ISIC_0034320.jpg
#   inflating: ./input/hmnist_28_28_L.csv
#   inflating: ./input/hmnist_28_28_RGB.csv
#   inflating: ./input/hmnist_8_8_L.csv
#   inflating: ./input/hmnist_8_8_RGB.csv
# ['ham10000_images_part_1', 'ham10000_images_part_2', 'HAM10000_images_part_1', 'HAM10000_metadata.csv', 'hmnist_8_8_RGB.csv', 'HAM10000_images_part_2', 'hmnist_28_28_L.csv', 'hmnist_8_8_L.csv', 'hmnist_28_28_RGB.csv']

# %%
data_dir = './input'
all_image_path = glob(os.path.join(data_dir, '*', '*.jpg'))
imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x for x in all_image_path}
lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'dermatofibroma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

# %%
def compute_img_mean_std(image_paths):
    """
        computing the mean and std of three channel on the whole dataset,
        first we should normalize the image from 0-255 to 0-1
    """

    img_h, img_w = 224, 224
    imgs = []
    means, stdevs = [], []

    for i in tqdm(range(len(image_paths))):
        img = cv2.imread(image_paths[i])
        img = cv2.resize(img, (img_h, img_w))
        imgs.append(img)

    imgs = np.stack(imgs, axis=3)
    print(imgs.shape)

    imgs = imgs.astype(np.float32) / 255.

    for i in range(3):
        pixels = imgs[:, :, i, :].ravel()  # resize to one row
        means.append(np.mean(pixels))
        stdevs.append(np.std(pixels))

    means.reverse()  # BGR --> RGB
    stdevs.reverse()

    print("normMean = {}".format(means))
    print("normStd = {}".format(stdevs))
    return means,stdevs

# %%
#norm_mean,norm_std = compute_img_mean_std(all_image_path)
norm_mean = [0.763038, 0.54564667, 0.57004464]
norm_std = [0.14092727, 0.15261286, 0.1699712]

# %%
df_original = pd.read_csv(os.path.join(data_dir, 'HAM10000_metadata.csv'))
df_original['path'] = df_original['image_id'].map(imageid_path_dict.get)
df_original['cell_type'] = df_original['dx'].map(lesion_type_dict.get)
df_original['cell_type_idx'] = pd.Categorical(df_original['cell_type']).codes
df_original.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                               path  \
# 0  ./input/HAM10000_images_part_1/ISIC_0027419.jpg
# 1  ./input/HAM10000_images_part_1/ISIC_0025030.jpg
# 2  ./input/HAM10000_images_part_1/ISIC_0026769.jpg
# 3  ./input/HAM10000_images_part_1/ISIC_0025661.jpg
# 4  ./input/HAM10000_images_part_2/ISIC_0031633.jpg
#
#                         cell_type  cell_type_idx
# 0  Benign keratosis-like lesions               2
# 1  Benign keratosis-like lesions               2
# 2  Benign keratosis-like lesions               2
# 3  Benign keratosis-like lesions               2
# 4  Benign keratosis-like lesions               2

# %%
# this will tell us how many images are associated with each lesion_id
df_undup = df_original.groupby('lesion_id').count()
# now we filter out lesion_id's that have only one image associated with it
df_undup = df_undup[df_undup['image_id'] == 1]
df_undup.reset_index(inplace=True)
df_undup.head()
# Out:
#      lesion_id  image_id  dx  dx_type  age  sex  localization  path  \
# 0  HAM_0000001         1   1        1    1    1             1     1
# 1  HAM_0000003         1   1        1    1    1             1     1
# 2  HAM_0000004         1   1        1    1    1             1     1
# 3  HAM_0000007         1   1        1    1    1             1     1
# 4  HAM_0000008         1   1        1    1    1             1     1
#
#    cell_type  cell_type_idx
# 0          1              1
# 1          1              1
# 2          1              1
# 3          1              1
# 4          1              1

# %%
# here we identify lesion_id's that have duplicate images and those that have only one image.
def get_duplicates(x):
    unique_list = list(df_undup['lesion_id'])
    if x in unique_list:
        return 'unduplicated'
    else:
        return 'duplicated'

# create a new colum that is a copy of the lesion_id column
df_original['duplicates'] = df_original['lesion_id']
# apply the function to this new column
df_original['duplicates'] = df_original['duplicates'].apply(get_duplicates)
df_original.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                               path  \
# 0  ./input/HAM10000_images_part_1/ISIC_0027419.jpg
# 1  ./input/HAM10000_images_part_1/ISIC_0025030.jpg
# 2  ./input/HAM10000_images_part_1/ISIC_0026769.jpg
# 3  ./input/HAM10000_images_part_1/ISIC_0025661.jpg
# 4  ./input/HAM10000_images_part_2/ISIC_0031633.jpg
#
#                         cell_type  cell_type_idx  duplicates
# 0  Benign keratosis-like lesions               2  duplicated
# 1  Benign keratosis-like lesions               2  duplicated
# 2  Benign keratosis-like lesions               2  duplicated
# 3  Benign keratosis-like lesions               2  duplicated
# 4  Benign keratosis-like lesions               2  duplicated

# %%
df_original['duplicates'].value_counts()
# Out:
# unduplicated    5514
# duplicated      4501
# Name: duplicates, dtype: int64

# %%
# now we filter out images that don't have duplicates
df_undup = df_original[df_original['duplicates'] == 'unduplicated']
df_undup.shape
# Out:
# (5514, 11)

# %%
# now we create a val set using df because we are sure that none of these images have augmented duplicates in the train set
y = df_undup['cell_type_idx']
_, df_val = train_test_split(df_undup, test_size=0.2, random_state=101, stratify=y)
df_val.shape
# Out:
# (1103, 11)

# %%
df_val['cell_type_idx'].value_counts()
# Out:
# 4    883
# 2     88
# 6     46
# 1     35
# 0     30
# 5     13
# 3      8
# Name: cell_type_idx, dtype: int64

# %%
# This set will be df_original excluding all rows that are in the val set
# This function identifies if an image is part of the train or val set.
def get_val_rows(x):
    # create a list of all the lesion_id's in the val set
    val_list = list(df_val['image_id'])
    if str(x) in val_list:
        return 'val'
    else:
        return 'train'

# identify train and val rows
# create a new colum that is a copy of the image_id column
df_original['train_or_val'] = df_original['image_id']
# apply the function to this new column
df_original['train_or_val'] = df_original['train_or_val'].apply(get_val_rows)
# filter out train rows
df_train = df_original[df_original['train_or_val'] == 'train']
print(len(df_train))
print(len(df_val))
# Out:
# 8912
# 1103

# %%
df_train['cell_type_idx'].value_counts()
# Out:
# 4    5822
# 6    1067
# 2    1011
# 1     479
# 0     297
# 5     129
# 3     107
# Name: cell_type_idx, dtype: int64

# %%
df_val['cell_type'].value_counts()
# Out:
# Melanocytic nevi                  883
# Benign keratosis-like lesions      88
# dermatofibroma                     46
# Basal cell carcinoma               35
# Actinic keratoses                  30
# Vascular lesions                   13
# Dermatofibroma                      8
# Name: cell_type, dtype: int64

# %%
# Copy fewer class to balance the number of 7 classes
data_aug_rate = [15,10,5,50,0,40,5]
for i in range(7):
    if data_aug_rate[i]:
        df_train=df_train.append([df_train.loc[df_train['cell_type_idx'] == i,:]]*(data_aug_rate[i]-1), ignore_index=True)
df_train['cell_type'].value_counts()
# Out:
# <ipython-input-15-b24def662a40>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train=df_train.append([df_train.loc[df_train['cell_type_idx'] == i,:]]*(data_aug_rate[i]-1), ignore_index=True)
# Melanocytic nevi                  5822
# Dermatofibroma                    5350
# dermatofibroma                    5335
# Vascular lesions                  5160
# Benign keratosis-like lesions     5055
# Basal cell carcinoma              4790
# Actinic keratoses                 4455
# Name: cell_type, dtype: int64

# %%
# # We can split the test set again in a validation set and a true test set:
# df_val, df_test = train_test_split(df_val, test_size=0.5)
df_train = df_train.reset_index()
df_val = df_val.reset_index()
# df_test = df_test.reset_index()

# %%
# feature_extract is a boolean that defines if we are finetuning or feature extracting. 
# If feature_extract = False, the model is finetuned and all model parameters are updated. 
# If feature_extract = True, only the last layer parameters are updated, the others remain fixed.
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):
    # Initialize these variables which will be set in this if statement. Each of these
    #   variables is model specific.
    model_ft = None
    input_size = 0

    if model_name == "resnet":
        """ Resnet18, resnet34, resnet50, resnet101
        """
        model_ft = models.resnet50(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs, num_classes)
        input_size = 224


    elif model_name == "vgg":
        """ VGG11_bn
        """
        model_ft = models.vgg11_bn(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224


    elif model_name == "densenet":
        """ Densenet121
        """
        model_ft = models.densenet121(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier.in_features
        model_ft.classifier = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "inception":
        """ Inception v3
        Be careful, expects (299,299) sized images and has auxiliary output
        """
        model_ft = models.inception_v3(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        # Handle the auxilary net
        num_ftrs = model_ft.AuxLogits.fc.in_features
        model_ft.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)
        # Handle the primary net
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs,num_classes)
        input_size = 299

    else:
        print("Invalid model name, exiting...")
        exit()
    return model_ft, input_size

# %%
# resnet,vgg,densenet,inception
model_name = 'densenet'
num_classes = 7
feature_extract = False
# Initialize the model for this run
model_ft, input_size = initialize_model(model_name, num_classes, feature_extract, use_pretrained=True)
# Define the device:
device = torch.device('cuda:0')
# Put the model on the device:
model = model_ft.to(device)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 249MB/s]

# %%
# norm_mean = (0.49139968, 0.48215827, 0.44653124)
# norm_std = (0.24703233, 0.24348505, 0.26158768)
# define the transformation of the train images.
train_transform = transforms.Compose([transforms.Resize((input_size,input_size)),transforms.RandomHorizontalFlip(),
                                      transforms.RandomVerticalFlip(),transforms.RandomRotation(20),
                                      transforms.ColorJitter(brightness=0.1, contrast=0.1, hue=0.1),
                                        transforms.ToTensor(), transforms.Normalize(norm_mean, norm_std)])
# define the transformation of the val images.
val_transform = transforms.Compose([transforms.Resize((input_size,input_size)), transforms.ToTensor(),
                                    transforms.Normalize(norm_mean, norm_std)])

# %%
# Define a pytorch dataloader for this dataset
class HAM10000(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        # Load data and get label
        X = Image.open(self.df['path'][index])
        y = torch.tensor(int(self.df['cell_type_idx'][index]))

        if self.transform:
            X = self.transform(X)

        return X, y

# %%
# Define the training set using the table train_df and using our defined transitions (train_transform)
training_set = HAM10000(df_train, transform=train_transform)
train_loader = DataLoader(training_set, batch_size=32, shuffle=True, num_workers=4)
# Same for the validation set:
validation_set = HAM10000(df_val, transform=train_transform)
val_loader = DataLoader(validation_set, batch_size=32, shuffle=False, num_workers=4)
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
# we use Adam optimizer, use cross entropy loss as our loss function
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss().to(device)

# %%
# this function is used during training process, to calculation the loss and accuracy
class AverageMeter(object):
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
total_loss_train, total_acc_train = [],[]
def train(train_loader, model, criterion, optimizer, epoch):
    model.train()
    train_loss = AverageMeter()
    train_acc = AverageMeter()
    curr_iter = (epoch - 1) * len(train_loader)
    for i, data in enumerate(train_loader):
        images, labels = data
        N = images.size(0)
        # print('image shape:',images.size(0), 'label shape',labels.size(0))
        images = Variable(images).to(device)
        labels = Variable(labels).to(device)

        optimizer.zero_grad()
        outputs = model(images)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        prediction = outputs.max(1, keepdim=True)[1]
        train_acc.update(prediction.eq(labels.view_as(prediction)).sum().item()/N)
        train_loss.update(loss.item())
        curr_iter += 1
        if (i + 1) % 100 == 0:
            print('[epoch %d], [iter %d / %d], [train loss %.5f], [train acc %.5f]' % (
                epoch, i + 1, len(train_loader), train_loss.avg, train_acc.avg))
            total_loss_train.append(train_loss.avg)
            total_acc_train.append(train_acc.avg)
    return train_loss.avg, train_acc.avg

# %%
def validate(val_loader, model, criterion, optimizer, epoch):
    model.eval()
    val_loss = AverageMeter()
    val_acc = AverageMeter()
    with torch.no_grad():
        for i, data in enumerate(val_loader):
            images, labels = data
            N = images.size(0)
            images = Variable(images).to(device)
            labels = Variable(labels).to(device)

            outputs = model(images)
            prediction = outputs.max(1, keepdim=True)[1]

            val_acc.update(prediction.eq(labels.view_as(prediction)).sum().item()/N)

            val_loss.update(criterion(outputs, labels).item())

    print('------------------------------------------------------------')
    print('[epoch %d], [val loss %.5f], [val acc %.5f]' % (epoch, val_loss.avg, val_acc.avg))
    print('------------------------------------------------------------')
    return val_loss.avg, val_acc.avg

# %%
epoch_num = 10
best_val_acc = 0
total_loss_val, total_acc_val = [],[]
for epoch in range(1, epoch_num+1):
    loss_train, acc_train = train(train_loader, model, criterion, optimizer, epoch)
    loss_val, acc_val = validate(val_loader, model, criterion, optimizer, epoch)
    total_loss_val.append(loss_val)
    total_acc_val.append(acc_val)
    if acc_val > best_val_acc:
        best_val_acc = acc_val
        print('*****************************************************')
        print('best record: [epoch %d], [val loss %.5f], [val acc %.5f]' % (epoch, loss_val, acc_val))
        print('*****************************************************')
# Out:
# [epoch 1], [iter 100 / 1124], [train loss 1.20963], [train acc 0.54438]
# [epoch 1], [iter 200 / 1124], [train loss 1.09032], [train acc 0.59531]
# [epoch 1], [iter 300 / 1124], [train loss 1.02266], [train acc 0.61854]
# [epoch 1], [iter 400 / 1124], [train loss 0.98262], [train acc 0.63516]
# [epoch 1], [iter 500 / 1124], [train loss 0.94705], [train acc 0.64981]
# [epoch 1], [iter 600 / 1124], [train loss 0.90658], [train acc 0.66349]
# [epoch 1], [iter 700 / 1124], [train loss 0.87922], [train acc 0.67353]
# [epoch 1], [iter 800 / 1124], [train loss 0.85630], [train acc 0.68199]
# [epoch 1], [iter 900 / 1124], [train loss 0.83661], [train acc 0.68948]
# [epoch 1], [iter 1000 / 1124], [train loss 0.81433], [train acc 0.69656]
# [epoch 1], [iter 1100 / 1124], [train loss 0.79892], [train acc 0.70165]
# ------------------------------------------------------------
# [epoch 1], [val loss 0.46753], [val acc 0.82107]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 1], [val loss 0.46753], [val acc 0.82107]
# *****************************************************
# [epoch 2], [iter 100 / 1124], [train loss 0.60518], [train acc 0.77156]
# [epoch 2], [iter 200 / 1124], [train loss 0.59810], [train acc 0.77297]
# [epoch 2], [iter 300 / 1124], [train loss 0.60433], [train acc 0.77083]
# [epoch 2], [iter 400 / 1124], [train loss 0.59057], [train acc 0.77516]
# [epoch 2], [iter 500 / 1124], [train loss 0.58279], [train acc 0.77881]
# [epoch 2], [iter 600 / 1124], [train loss 0.57312], [train acc 0.78156]
# [epoch 2], [iter 700 / 1124], [train loss 0.57327], [train acc 0.78076]
# [epoch 2], [iter 800 / 1124], [train loss 0.56797], [train acc 0.78180]
# [epoch 2], [iter 900 / 1124], [train loss 0.56300], [train acc 0.78330]
# [epoch 2], [iter 1000 / 1124], [train loss 0.55585], [train acc 0.78647]
# [epoch 2], [iter 1100 / 1124], [train loss 0.55049], [train acc 0.78841]
# ------------------------------------------------------------
# [epoch 2], [val loss 0.50941], [val acc 0.81024]
# ------------------------------------------------------------
# [epoch 3], [iter 100 / 1124], [train loss 0.46586], [train acc 0.82250]
# [epoch 3], [iter 200 / 1124], [train loss 0.47723], [train acc 0.81703]
# [epoch 3], [iter 300 / 1124], [train loss 0.47237], [train acc 0.82042]
# [epoch 3], [iter 400 / 1124], [train loss 0.47592], [train acc 0.81977]
# [epoch 3], [iter 500 / 1124], [train loss 0.46531], [train acc 0.82381]
# [epoch 3], [iter 600 / 1124], [train loss 0.46189], [train acc 0.82568]
# [epoch 3], [iter 700 / 1124], [train loss 0.45882], [train acc 0.82585]
# [epoch 3], [iter 800 / 1124], [train loss 0.45751], [train acc 0.82719]
# [epoch 3], [iter 900 / 1124], [train loss 0.45714], [train acc 0.82743]
# [epoch 3], [iter 1000 / 1124], [train loss 0.45347], [train acc 0.82913]
# [epoch 3], [iter 1100 / 1124], [train loss 0.45166], [train acc 0.83051]
# ------------------------------------------------------------
# [epoch 3], [val loss 0.32385], [val acc 0.88815]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 3], [val loss 0.32385], [val acc 0.88815]
# *****************************************************
# [epoch 4], [iter 100 / 1124], [train loss 0.38064], [train acc 0.85938]
# [epoch 4], [iter 200 / 1124], [train loss 0.37868], [train acc 0.85719]
# [epoch 4], [iter 300 / 1124], [train loss 0.38223], [train acc 0.85740]
# [epoch 4], [iter 400 / 1124], [train loss 0.38410], [train acc 0.85609]
# [epoch 4], [iter 500 / 1124], [train loss 0.39135], [train acc 0.85181]
# [epoch 4], [iter 600 / 1124], [train loss 0.38904], [train acc 0.85234]
# [epoch 4], [iter 700 / 1124], [train loss 0.38947], [train acc 0.85246]
# [epoch 4], [iter 800 / 1124], [train loss 0.38711], [train acc 0.85281]
# [epoch 4], [iter 900 / 1124], [train loss 0.38390], [train acc 0.85368]
# [epoch 4], [iter 1000 / 1124], [train loss 0.37943], [train acc 0.85528]
# [epoch 4], [iter 1100 / 1124], [train loss 0.37687], [train acc 0.85568]
# ------------------------------------------------------------
# [epoch 4], [val loss 0.39607], [val acc 0.87042]
# ------------------------------------------------------------
# [epoch 5], [iter 100 / 1124], [train loss 0.33661], [train acc 0.86687]
# [epoch 5], [iter 200 / 1124], [train loss 0.32985], [train acc 0.86922]
# [epoch 5], [iter 300 / 1124], [train loss 0.33578], [train acc 0.86719]
# [epoch 5], [iter 400 / 1124], [train loss 0.34233], [train acc 0.86672]
# [epoch 5], [iter 500 / 1124], [train loss 0.33770], [train acc 0.86813]
# [epoch 5], [iter 600 / 1124], [train loss 0.33146], [train acc 0.86984]
# [epoch 5], [iter 700 / 1124], [train loss 0.32963], [train acc 0.87054]
# [epoch 5], [iter 800 / 1124], [train loss 0.32702], [train acc 0.87277]
# [epoch 5], [iter 900 / 1124], [train loss 0.32875], [train acc 0.87281]
# [epoch 5], [iter 1000 / 1124], [train loss 0.32789], [train acc 0.87356]
# [epoch 5], [iter 1100 / 1124], [train loss 0.32560], [train acc 0.87480]
# ------------------------------------------------------------
# [epoch 5], [val loss 0.35961], [val acc 0.86405]
# ------------------------------------------------------------
# [epoch 6], [iter 100 / 1124], [train loss 0.30199], [train acc 0.88844]
# [epoch 6], [iter 200 / 1124], [train loss 0.28969], [train acc 0.88922]
# [epoch 6], [iter 300 / 1124], [train loss 0.28899], [train acc 0.88844]
# [epoch 6], [iter 400 / 1124], [train loss 0.28978], [train acc 0.89023]
# [epoch 6], [iter 500 / 1124], [train loss 0.28976], [train acc 0.88969]
# [epoch 6], [iter 600 / 1124], [train loss 0.29239], [train acc 0.88964]
# [epoch 6], [iter 700 / 1124], [train loss 0.29440], [train acc 0.88938]
# [epoch 6], [iter 800 / 1124], [train loss 0.29671], [train acc 0.88844]
# [epoch 6], [iter 900 / 1124], [train loss 0.29450], [train acc 0.88931]
# [epoch 6], [iter 1000 / 1124], [train loss 0.29175], [train acc 0.88991]
# [epoch 6], [iter 1100 / 1124], [train loss 0.28820], [train acc 0.89108]
# ------------------------------------------------------------
# [epoch 6], [val loss 0.37686], [val acc 0.85857]
# ------------------------------------------------------------
# [epoch 7], [iter 100 / 1124], [train loss 0.25160], [train acc 0.89812]
# [epoch 7], [iter 200 / 1124], [train loss 0.24627], [train acc 0.90172]
# [epoch 7], [iter 300 / 1124], [train loss 0.25106], [train acc 0.90167]
# [epoch 7], [iter 400 / 1124], [train loss 0.25343], [train acc 0.90172]
# [epoch 7], [iter 500 / 1124], [train loss 0.25509], [train acc 0.90100]
# [epoch 7], [iter 600 / 1124], [train loss 0.25400], [train acc 0.90187]
# [epoch 7], [iter 700 / 1124], [train loss 0.25232], [train acc 0.90308]
# [epoch 7], [iter 800 / 1124], [train loss 0.25224], [train acc 0.90309]
# [epoch 7], [iter 900 / 1124], [train loss 0.25111], [train acc 0.90431]
# [epoch 7], [iter 1000 / 1124], [train loss 0.24797], [train acc 0.90528]
# [epoch 7], [iter 1100 / 1124], [train loss 0.24720], [train acc 0.90545]
# ------------------------------------------------------------
# [epoch 7], [val loss 0.39479], [val acc 0.86661]
# ------------------------------------------------------------
# [epoch 8], [iter 100 / 1124], [train loss 0.22455], [train acc 0.91625]
# [epoch 8], [iter 200 / 1124], [train loss 0.21551], [train acc 0.91906]
# [epoch 8], [iter 300 / 1124], [train loss 0.21491], [train acc 0.91844]
# [epoch 8], [iter 400 / 1124], [train loss 0.21538], [train acc 0.91664]
# [epoch 8], [iter 500 / 1124], [train loss 0.21497], [train acc 0.91812]
# [epoch 8], [iter 600 / 1124], [train loss 0.21626], [train acc 0.91812]
# [epoch 8], [iter 700 / 1124], [train loss 0.21787], [train acc 0.91768]
# [epoch 8], [iter 800 / 1124], [train loss 0.21934], [train acc 0.91734]
# [epoch 8], [iter 900 / 1124], [train loss 0.22169], [train acc 0.91635]
# [epoch 8], [iter 1000 / 1124], [train loss 0.22073], [train acc 0.91694]
# [epoch 8], [iter 1100 / 1124], [train loss 0.21965], [train acc 0.91656]
# ------------------------------------------------------------
# [epoch 8], [val loss 0.47920], [val acc 0.84262]
# ------------------------------------------------------------
# [epoch 9], [iter 100 / 1124], [train loss 0.22165], [train acc 0.91469]
# [epoch 9], [iter 200 / 1124], [train loss 0.23108], [train acc 0.91312]
# [epoch 9], [iter 300 / 1124], [train loss 0.22683], [train acc 0.91552]
# [epoch 9], [iter 400 / 1124], [train loss 0.22202], [train acc 0.91648]
# [epoch 9], [iter 500 / 1124], [train loss 0.21275], [train acc 0.92087]
# [epoch 9], [iter 600 / 1124], [train loss 0.20852], [train acc 0.92281]
# [epoch 9], [iter 700 / 1124], [train loss 0.20435], [train acc 0.92429]
# [epoch 9], [iter 800 / 1124], [train loss 0.20212], [train acc 0.92512]
# [epoch 9], [iter 900 / 1124], [train loss 0.19941], [train acc 0.92597]
# [epoch 9], [iter 1000 / 1124], [train loss 0.19745], [train acc 0.92644]
# [epoch 9], [iter 1100 / 1124], [train loss 0.19519], [train acc 0.92733]
# ------------------------------------------------------------
# [epoch 9], [val loss 0.28814], [val acc 0.89810]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 9], [val loss 0.28814], [val acc 0.89810]
# *****************************************************
# [epoch 10], [iter 100 / 1124], [train loss 0.17450], [train acc 0.93219]
# [epoch 10], [iter 200 / 1124], [train loss 0.17531], [train acc 0.93063]
# [epoch 10], [iter 300 / 1124], [train loss 0.18169], [train acc 0.92906]
# [epoch 10], [iter 400 / 1124], [train loss 0.18905], [train acc 0.92688]
# [epoch 10], [iter 500 / 1124], [train loss 0.19699], [train acc 0.92506]
# [epoch 10], [iter 600 / 1124], [train loss 0.19503], [train acc 0.92604]
# [epoch 10], [iter 700 / 1124], [train loss 0.19270], [train acc 0.92714]
# [epoch 10], [iter 800 / 1124], [train loss 0.18800], [train acc 0.92902]
# [epoch 10], [iter 900 / 1124], [train loss 0.18571], [train acc 0.93000]
# [epoch 10], [iter 1000 / 1124], [train loss 0.18549], [train acc 0.93019]
# [epoch 10], [iter 1100 / 1124], [train loss 0.18449], [train acc 0.93045]
# ------------------------------------------------------------
# [epoch 10], [val loss 0.31999], [val acc 0.91327]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 10], [val loss 0.31999], [val acc 0.91327]
# *****************************************************

# %%
fig = plt.figure(num = 2)
fig1 = fig.add_subplot(2,1,1)
fig2 = fig.add_subplot(2,1,2)
fig1.plot(total_loss_train, label = 'training loss')
fig1.plot(total_acc_train, label = 'training accuracy')
fig2.plot(total_loss_val, label = 'validation loss')
fig2.plot(total_acc_val, label = 'validation accuracy')
plt.legend()
plt.show()

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
model.eval()
y_label = []
y_predict = []
with torch.no_grad():
    for i, data in enumerate(val_loader):
        images, labels = data
        N = images.size(0)
        images = Variable(images).to(device)
        outputs = model(images)
        prediction = outputs.max(1, keepdim=True)[1]
        y_label.extend(labels.cpu().numpy())
        y_predict.extend(np.squeeze(prediction.cpu().numpy().T))

# compute the confusion matrix
confusion_mtx = confusion_matrix(y_label, y_predict)
# plot the confusion matrix
plot_labels = ['akiec', 'bcc', 'bkl', 'df', 'nv', 'vasc','mel']
plot_confusion_matrix(confusion_mtx, plot_labels)

# %%
# Generate a classification report
report = classification_report(y_label, y_predict, target_names=plot_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        akiec       0.71      0.67      0.69        30
#          bcc       0.76      0.91      0.83        35
#          bkl       0.71      0.69      0.70        88
#           df       0.75      0.75      0.75         8
#           nv       0.97      0.97      0.97       883
#         vasc       1.00      0.92      0.96        13
#          mel       0.50      0.48      0.49        46
#
#     accuracy                           0.91      1103
#    macro avg       0.77      0.77      0.77      1103
# weighted avg       0.91      0.91      0.91      1103
